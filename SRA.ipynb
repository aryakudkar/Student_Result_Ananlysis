# %%
import pandas as pd
import numpy as np

# %%
dataset_5A=pd.read_excel("D:/SRA_Data.xlsx",sheet_name="5A")
dataset_5B=pd.read_excel("D:/SRA_Data.xlsx",sheet_name="5B")
dataset_6A=pd.read_excel("D:/SRA_Data.xlsx",sheet_name="6A")
dataset_6B=pd.read_excel("D:/SRA_Data.xlsx",sheet_name="6B")
dataset_7A=pd.read_excel("D:/SRA_Data.xlsx",sheet_name="7A")
dataset_7B=pd.read_excel("D:/SRA_Data.xlsx",sheet_name="7B")
dataset_8A=pd.read_excel("D:/SRA_Data.xlsx",sheet_name="8A")
dataset_8B=pd.read_excel("D:/SRA_Data.xlsx",sheet_name="8B")
dataset_9A=pd.read_excel("D:/SRA_Data.xlsx",sheet_name="9A")
dataset_9B=pd.read_excel("D:/SRA_Data.xlsx",sheet_name="9B")
dataset_overall=pd.read_excel("D:/SRA_Data.xlsx",sheet_name="Overall")

# %%
#5TH STANDARD

# %%
dataset_5A.head()
# Out:
#    Roll No.               Student Name  Marathi(50)  Hindi(50)  English(50)  \
# 0         1       Arde Netra Satyawan            33         36           29
# 1         2  Baraskar Vidhi Shashikant           32         44           34
# 2         3   Bhekere Shravani Nilesh            39         41           31
# 3         4       Chavan Purvi Rupesh            37         42           36
# 4         5   Deshmukh Swara Gaurihar            44         47           38
#
#    Maths(50)  EVS(50)  Art(100)  Work Experience(100)  Health Education (100)  \
# 0         21       30        84                    55                      66
# 1         22       33        89                    78                      88
# 2         31       38        90                    98                      79
# 3         31       39        57                    65                      86
# 4         48       46        68                    87                      57
#
# ...

# %%
dataset_5A.tail()
# Out:
#     Roll No.           Student Name  Marathi(50)  Hindi(50)  English(50)  \
# 57        58  Sankpal Satyam Ashok            33         35           27
# 58        59   Shelar Vedant Vijay            43         39           49
# 59        60   Shinde Ayush Deepak            28         38           32
# 60        61     Teli Parth Laxman            31         42           32
# 61        62  Kadam Shravani Sanjay           29         40           26
#
#     Maths(50)  EVS(50)  Art(100)  Work Experience(100)  \
# 57         25       28        82                    78
# 58         40       30        72                    90
# 59         31       31        64                    57
# 60         30       35        90                    68
# 61         19       23        93                    77
#
#     Health Education (100)  Total(250) No. of Subjects Failed  \
# 57                      87         148                      -
# 58                      80         201                      -
# ...

# %%
dataset_5A.sample(5)
# Out:
#     Roll No.                 Student Name  Marathi(50)  Hindi(50)  \
# 28        29   Shinde Vedanshree Sandeep            36         44
# 5          6  Devrukhkar Kritika Shivaji            37         41
# 47        48       Neman Ritesh Ravindra            38         48
# 56        57       Raut Mayuresh Bhikaji            40         44
# 14        15    Korgaonkar Shubhra Tejas            35         46
#
#     English(50)  Maths(50)  EVS(50)  Art(100)  Work Experience(100)  \
# 28           36         31       40        57                    87
# 5            36         36       31        89                    95
# 47           48         48       45        89                    95
# 56           41         39       44        94                    89
# 14           48         41       40        87                    84
#
#     Health Education (100)  Total(250) No. of Subjects Failed  \
# 28                      75         187                      -
# ...

# %%
dataset_5A.shape
# Out:
# (62, 15)

# %%
print("Number of Rows:",dataset_5A.shape[0])
print("Number of Columns:",dataset_5A.shape[1])
# Out:
# Number of Rows: 62
# Number of Columns: 15

# %%
dataset_5A.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Roll No.                62 non-null     int64
#  1   Student Name            62 non-null     object
#  2   Marathi(50)             62 non-null     int64
#  3   Hindi(50)               62 non-null     int64
#  4   English(50)             62 non-null     int64
#  5   Maths(50)               62 non-null     int64
#  6   EVS(50)                 62 non-null     int64
#  7   Art(100)                62 non-null     int64
#  8   Work Experience(100)    62 non-null     int64
#  9   Health Education (100)  62 non-null     int64
#  10  Total(250)              62 non-null     int64
#  11  No. of Subjects Failed  62 non-null     object
#  12  Percentage(100%)        62 non-null     float64
#  13  Grade                   62 non-null     object
# ...

# %%
dataset_5A.isnull().sum()
# Out:
# Roll No.                  0
# Student Name              0
# Marathi(50)               0
# Hindi(50)                 0
# English(50)               0
# Maths(50)                 0
# EVS(50)                   0
# Art(100)                  0
# Work Experience(100)      0
# Health Education (100)    0
# Total(250)                0
# No. of Subjects Failed    0
# Percentage(100%)          0
# Grade                     0
# Remark                    0
# dtype: int64

# %%
dataset_5A_dup=dataset_5A.duplicated().any()
print(dataset_5A_dup)
# Out:
# False

# %%
dataset_5A.describe()
# Out:
#         Roll No.  Marathi(50)  Hindi(50)  English(50)  Maths(50)    EVS(50)  \
# count  62.000000    62.000000  62.000000    62.000000  62.000000  62.000000
# mean   31.500000    34.419355  41.145161    34.774194  32.016129  33.387097
# std    18.041619     4.970564   4.841239     7.689506   8.526702   7.308999
# min     1.000000    18.000000  20.000000    16.000000  15.000000  13.000000
# 25%    16.250000    32.000000  38.250000    29.250000  25.500000  28.250000
# 50%    31.500000    35.000000  42.000000    35.000000  31.000000  33.500000
# 75%    46.750000    37.750000  45.000000    39.750000  39.750000  39.000000
# max    62.000000    44.000000  48.000000    50.000000  50.000000  46.000000
#
#         Art(100)  Work Experience(100)  Health Education (100)  Total(250)  \
# count  62.000000             62.000000               62.000000   62.000000
# mean   78.741935             79.048387               78.516129  175.741935
# ...

# %%
dataset_5B.head()
# Out:
#    Roll No.              Student Name  Marathi(50)  Hindi(50)  English(50)  \
# 0         1      Aadam Hansika Mohan            18         18           22
# 1         2  Bagle Nisha Dnyaneshwar            26         41           24
# 2         3        Barje Kavya Nakul             8         21           18
# 3         4    Barthare Chetna Vijay            24         32           32
# 4         5     Bendure Nidhi Maruti            18         35           28
#
#    Maths(50)  EVS(50)  Art(100)  Work Experience(100)  Health Education (100)  \
# 0         18       18        94                    90                      82
# 1         22       27        82                    84                      72
# 2         13        8        72                    89                      64
# 3         22       25        64                    90                      90
# 4         25       22        90                    57                      93
#
# ...

# %%
dataset_5B.tail()
# Out:
#     Roll No.             Student Name  Marathi(50)  Hindi(50)  English(50)  \
# 53        54  Shinde Shravan Ravindra           34         46           36
# 54        55   Shirke Manthan Sandesh           23         26           23
# 55        56      Ujaal Arya Ravindra           25         29           23
# 56        57        Warik Harsh Manoj           20         22           34
# 57        58      Varthe Nikhil Vinod           18         20           18
#
#     Maths(50)  EVS(50)  Art(100)  Work Experience(100)  \
# 53         26       27        89                    98
# 54         18       22        66                    84
# 55         18       25        90                    90
# 56         29       30        93                    80
# 57         18       18        78                    67
#
#     Health Education (100)  Total(250) No. of Subjects Failed  \
# 53                      87         169                      -
# ...

# %%
dataset_5B.shape
# Out:
# (58, 15)

# %%
print("Number of Rows:",dataset_5B.shape[0])
print("Number of Columns:",dataset_5B.shape[1])
# Out:
# Number of Rows: 58
# Number of Columns: 15

# %%
dataset_5B.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Roll No.                58 non-null     int64
#  1   Student Name            58 non-null     object
#  2   Marathi(50)             58 non-null     int64
#  3   Hindi(50)               58 non-null     int64
#  4   English(50)             58 non-null     int64
#  5   Maths(50)               58 non-null     int64
#  6   EVS(50)                 58 non-null     int64
#  7   Art(100)                58 non-null     int64
#  8   Work Experience(100)    58 non-null     int64
#  9   Health Education (100)  58 non-null     int64
#  10  Total(250)              58 non-null     int64
#  11  No. of Subjects Failed  58 non-null     object
#  12  Percentage(100%)        58 non-null     float64
#  13  Grade                   58 non-null     object
# ...

# %%
dataset_5B.isnull().sum()
# Out:
# Roll No.                  0
# Student Name              0
# Marathi(50)               0
# Hindi(50)                 0
# English(50)               0
# Maths(50)                 0
# EVS(50)                   0
# Art(100)                  0
# Work Experience(100)      0
# Health Education (100)    0
# Total(250)                0
# No. of Subjects Failed    0
# Percentage(100%)          0
# Grade                     0
# Remark                    0
# dtype: int64

# %%
dataset_5B_dup=dataset_5B.duplicated().any()
print(dataset_5B_dup)
# Out:
# False

# %%
dataset_5B.describe()
# Out:
#         Roll No.  Marathi(50)  Hindi(50)  English(50)  Maths(50)    EVS(50)  \
# count  58.000000    58.000000  58.000000    58.000000  58.000000  58.000000
# mean   29.500000    23.362069  32.448276    23.965517  22.172414  23.310345
# std    16.886879     7.897808   9.599292     9.224235   6.391161   7.317863
# min     1.000000     5.000000  11.000000     5.000000   9.000000   8.000000
# 25%    15.250000    18.000000  23.000000    18.000000  18.000000  18.250000
# 50%    29.500000    22.500000  33.000000    21.500000  21.000000  23.000000
# 75%    43.750000    28.000000  40.000000    32.000000  26.000000  27.000000
# max    58.000000    41.000000  48.000000    42.000000  38.000000  40.000000
#
#         Art(100)  Work Experience(100)  Health Education (100)  Total(250)  \
# count  58.000000             58.000000               58.000000   58.000000
# mean   80.551724             80.327586               79.551724  125.258621
# ...

# %%
#6TH STANDARD

# %%
dataset_6A.head()
# Out:
#    Roll No.            Student Name  Marathi(100)  Hindi(100)  English(100)  \
# 0         1     Aragade Prachi Raju            84          85            91
# 1         2  Andhere Aaradhya Sumit            89          73            75
# 2         3    Baying Pradnya Umesh            87          84            75
# 3         4       Bare Manvi Mahesh            77          83            90
# 4         5   Bhosale Devika Vikram            89          89            90
#
#    Maths(100)  Science(100)  Social Science(100)  Art(100)  \
# 0          81            65                   93        86
# 1          53            57                   63        88
# 2          68            73                   91        93
# 3          61            53                   82        92
# 4          89            50                   96        91
#
#    Work Experience(100)  Health Education(100)  Total(900)  \
# 0                    98                     74         757
# ...

# %%
dataset_6A.tail()
# Out:
#     Roll No.            Student Name  Marathi(100)  Hindi(100)  English(100)  \
# 49        50  Shikhara Vedant Vijaya            80          75            84
# 50        51     Tambe Sambhav Dipak            71          71            76
# 51        52       Todkar Avish Ajit            67          63            78
# 52        53     Ujal Shreyas Suresh            82          84            86
# 53        54   Wadekar Shravan Vijay            84          91            91
#
#     Maths(100)  Science(100)  Social Science(100)  Art(100)  \
# 49          74            51                   62        94
# 50          80            54                   61        93
# 51          71            54                   69        84
# 52          87            85                   94        89
# 53          92            88                   94        79
#
#     Work Experience(100)  Health Education(100)  Total(900)  \
# 49                    67                     77         664
# ...

# %%
dataset_6A.shape
# Out:
# (55, 25)

# %%
print("Number of Rows:",dataset_6A.shape[0])
print("Number of Columns:",dataset_6A.shape[1])
# Out:
# Number of Rows: 54
# Number of Columns: 16

# %%
dataset_6A.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Roll No.                54 non-null     int64
#  1   Student Name            54 non-null     object
#  2   Marathi(100)            54 non-null     int64
#  3   Hindi(100)              54 non-null     int64
#  4   English(100)            54 non-null     int64
#  5   Maths(100)              54 non-null     int64
#  6   Science(100)            54 non-null     int64
#  7   Social Science(100)     54 non-null     int64
#  8   Art(100)                54 non-null     int64
#  9   Work Experience(100)    54 non-null     int64
#  10  Health Education(100)   54 non-null     int64
#  11  Total(900)              54 non-null     int64
#  12  No. of Subjects Failed  54 non-null     object
#  13  Percentage(100%)        54 non-null     float64
# ...

# %%
dataset_6A.isnull().sum()
# Out:
# Roll No.                  0
# Student Name              0
# Marathi(100)              0
# Hindi(100)                0
# English(100)              0
# Maths(100)                0
# Science(100)              0
# Social Science(100)       0
# Art(100)                  0
# Work Experience(100)      0
# Health Education(100)     0
# Total(900)                0
# No. of Subjects Failed    0
# Percentage(100%)          0
# Grade                     0
# Remark                    0
# dtype: int64

# %%
dataset_6A_dup=dataset_6A.duplicated().any()
print(dataset_6A_dup)
# Out:
# False

# %%
dataset_6A.describe()
# Out:
#         Roll No.  Marathi(100)  Hindi(100)  English(100)  Maths(100)  \
# count  54.000000     54.000000   54.000000     54.000000   54.000000
# mean   27.500000     76.796296   76.185185     79.851852   69.962963
# std    15.732133      6.301781    7.912431      7.685830   11.598573
# min     1.000000     64.000000   59.000000     63.000000   45.000000
# 25%    14.250000     73.000000   71.000000     75.000000   62.250000
# 50%    27.500000     77.000000   77.000000     80.000000   68.500000
# 75%    40.750000     80.750000   82.750000     84.000000   76.750000
# max    54.000000     89.000000   91.000000     96.000000   97.000000
#
#        Science(100)  Social Science(100)   Art(100)  Work Experience(100)  \
# count     54.000000            54.000000  54.000000             54.000000
# mean      57.074074            73.240741  86.222222             87.000000
# std       13.877975            13.549260   4.529429              8.910456
# ...

# %%
dataset_6B.head()
# Out:
#    Roll No.            Student Name  Marathi(100)  Hindi(100)  English(100)  \
# 0         1    Adulkar Gauravi Ajit            55          49            74
# 1         2  Aaher Aradhana Sandeep            51          52            73
# 2         3   Balkate Prachi Nilesh            79          75            83
# 3         4  Bawkar Saloni Ravindra            71          57            74
# 4         5    Chavan Antara Sandip            78          69            86
#
#    Maths(100)  Science(100)  Social Science(100)  Art(100)  \
# 0          57            49                   53        84
# 1          52            41                   41        79
# 2          62            73                   71        89
# 3          54            55                   59        75
# 4          68            58                   75        86
#
#    Work Experience(100)  Health Education(100)  Total(900)  \
# 0                    86                     80         587
# ...

# %%
dataset_6B.tail()
# Out:
#     Roll No.            Student Name  Marathi(100)  Hindi(100)  English(100)  \
# 39        40     Mehtar Sahil Deepak            68          71            73
# 40        41  Rewale Devansh Vishwas            47          58            55
# 41        42   Sawant Shreyas Sanjay            62          57            50
# 42        43     Sutar Yash Mahendra             0           0             0
# 43        44     Tandule Soham Vilas            66          57            47
#
#     Maths(100)  Science(100)  Social Science(100)  Art(100)  \
# 39          48            56                   64        72
# 40          58            45                   50        89
# 41          46            46                   51        81
# 42           0             0                    0         0
# 43          43            52                   46        74
#
#     Work Experience(100)  Health Education(100)  Total(900)  \
# 39                    61                     83         596
# ...

# %%
dataset_6B.shape
# Out:
# (44, 16)

# %%
print("Number of Rows:",dataset_6B.shape[0])
print("Number of Columns:",dataset_6B.shape[1])
# Out:
# Number of Rows: 44
# Number of Columns: 16

# %%
dataset_6B.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Roll No.                44 non-null     int64
#  1   Student Name            44 non-null     object
#  2   Marathi(100)            44 non-null     int64
#  3   Hindi(100)              44 non-null     int64
#  4   English(100)            44 non-null     int64
#  5   Maths(100)              44 non-null     int64
#  6   Science(100)            44 non-null     int64
#  7   Social Science(100)     44 non-null     int64
#  8   Art(100)                44 non-null     int64
#  9   Work Experience(100)    44 non-null     int64
#  10  Health Education(100)   44 non-null     int64
#  11  Total(900)              44 non-null     int64
#  12  No. of Subjects Failed  44 non-null     object
#  13  Percentage(100%)        44 non-null     float64
# ...

# %%
dataset_6B.isnull().sum()
# Out:
# Roll No.                  0
# Student Name              0
# Marathi(100)              0
# Hindi(100)                0
# English(100)              0
# Maths(100)                0
# Science(100)              0
# Social Science(100)       0
# Art(100)                  0
# Work Experience(100)      0
# Health Education(100)     0
# Total(900)                0
# No. of Subjects Failed    0
# Percentage(100%)          0
# Grade                     0
# Remark                    0
# dtype: int64

# %%
dataset_6B_dup=dataset_6B.duplicated().any()
print(dataset_6B_dup)
# Out:
# False

# %%
dataset_6B.describe()
# Out:
#         Roll No.  Marathi(100)  Hindi(100)  English(100)  Maths(100)  \
# count  44.000000     44.000000   44.000000     44.000000   44.000000
# mean   22.500000     60.750000   60.136364     63.909091   50.931818
# std    12.845233     16.175096   16.029901     17.483305   13.026623
# min     1.000000      0.000000    0.000000      0.000000    0.000000
# 25%    11.750000     55.750000   57.000000     57.750000   48.000000
# 50%    22.500000     65.500000   62.000000     66.500000   52.000000
# 75%    33.250000     69.000000   69.000000     74.000000   58.000000
# max    44.000000     84.000000   90.000000     86.000000   68.000000
#
#        Science(100)  Social Science(100)   Art(100)  Work Experience(100)  \
# count     44.000000            44.000000  44.000000             44.000000
# mean      51.454545            51.159091  78.136364             66.409091
# std       15.112685            15.929997  18.700318             18.773210
# ...

# %%
#7TH STANDARD

# %%
dataset_7A.head()
# Out:
#    Roll No.              Student Name  Marathi(100)  Hindi(100)  English(100)  \
# 0         1        Agre Riya Gopinath            76          74            73
# 1         2  Ambekar Vaishnavi Haresh            85          50            80
# 2         3      Chavan Sai Dhananjay            86          80            81
# 3         4      Dalvi Manaswi Suresh            85          68            79
# 4         5      Davande Diksha Anant            84          72            80
#
#    Maths(100)  Science(100)  Social Science(100)  Art(100)  \
# 0          54            41                   54        81
# 1          59            45                   48        97
# 2          63            51                   70        88
# 3          68            49                   69        87
# 4          51            41                   55        85
#
#    Work Experience(100)  Health Education(100)  Total(900)  \
# 0                    74                     83         610
# ...

# %%
dataset_7A.tail()
# Out:
#     Roll No.            Student Name  Marathi(100)  Hindi(100)  English(100)  \
# 62        63      Salvi Manas Milind            93          60            84
# 63        64   Sankpal Manthan Ashok            91          59            80
# 64        65    Shinde Vignesh Vinod            90          76            62
# 65        66  Varanakar Tanmay Anant            95          75            68
# 66        67    Lotlikar Yash Dinesh            87          80            88
#
#     Maths(100)  Science(100)  Social Science(100)  Art(100)  \
# 62          60            65                   62        71
# 63          56            45                   75        87
# 64          62            41                   61        95
# 65          85            41                   56        88
# 66          79            44                   50        75
#
#     Work Experience(100)  Health Education(100)  Total(900)  \
# 62                    71                     71         637
# ...

# %%
dataset_7A.shape
# Out:
# (67, 16)

# %%
print("Number of Rows:",dataset_7A.shape[0])
print("Number of Columns:",dataset_7A.shape[1])
# Out:
# Number of Rows: 67
# Number of Columns: 16

# %%
dataset_7A.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Roll No.                67 non-null     int64
#  1   Student Name            67 non-null     object
#  2   Marathi(100)            67 non-null     int64
#  3   Hindi(100)              67 non-null     int64
#  4   English(100)            67 non-null     int64
#  5   Maths(100)              67 non-null     int64
#  6   Science(100)            67 non-null     int64
#  7   Social Science(100)     67 non-null     int64
#  8   Art(100)                67 non-null     int64
#  9   Work Experience(100)    67 non-null     int64
#  10  Health Education(100)   67 non-null     int64
#  11  Total(900)              67 non-null     int64
#  12  No. of Subjects Failed  67 non-null     object
#  13  Percentage(100%)        67 non-null     float64
# ...

# %%
dataset_7A.isnull().sum()
# Out:
# Roll No.                  0
# Student Name              0
# Marathi(100)              0
# Hindi(100)                0
# English(100)              0
# Maths(100)                0
# Science(100)              0
# Social Science(100)       0
# Art(100)                  0
# Work Experience(100)      0
# Health Education(100)     0
# Total(900)                0
# No. of Subjects Failed    0
# Percentage(100%)          0
# Grade                     0
# Remark                    0
# dtype: int64

# %%
dataset_7A_dup=dataset_7A.duplicated().any()
print(dataset_7A_dup)
# Out:
# False

# %%
dataset_7A.describe()
# Out:
#         Roll No.  Marathi(100)  Hindi(100)  English(100)  Maths(100)  \
# count  67.000000     67.000000   67.000000     67.000000   67.000000
# mean   34.000000     87.074627   70.328358     81.492537   62.850746
# std    19.485037      5.252167    8.002628     10.541941   10.250283
# min     1.000000     75.000000   50.000000     57.000000   43.000000
# 25%    17.500000     84.000000   64.000000     76.000000   58.000000
# 50%    34.000000     88.000000   71.000000     84.000000   61.000000
# 75%    50.500000     91.000000   76.000000     89.000000   68.000000
# max    67.000000     97.000000   84.000000     98.000000   88.000000
#
#        Science(100)  Social Science(100)   Art(100)  Work Experience(100)  \
# count     67.000000            67.000000  67.000000             67.000000
# mean      51.238806            68.432836  84.149254             83.582090
# std       11.145171            12.866710   6.169951             10.105728
# ...

# %%
dataset_7B.head()
# Out:
#    Roll No.             Student Name  Marathi(100)  Hindi(100)  English(100)  \
# 0         1   Alugade Ritika Santosh            81          73            81
# 1         2   Arsekar Antara Shankar            65          57            62
# 2         3    Bacche Prachi Shivaji            76          64            79
# 3         4       Bane Samika Sanjay            47          43            63
# 4         5  Bhangra Ruperi Santhosh            77          66            73
#
#    Maths(100)  Science(100)  Social Science(100)  Art(100)  \
# 0          70            52                   62        93
# 1          62            41                   54        76
# 2          63            61                   64        77
# 3          61            41                   45        72
# 4          64            41                   44        88
#
#    Work Experience(100)  Health Education(100)  Total(900)  \
# 0                    85                     84         681
# ...

# %%
dataset_7B.tail()
# Out:
#     Roll No.           Student Name  Marathi(100)  Hindi(100)  English(100)  \
# 58        59   Tawde Darshan Sanjay            64          55            55
# 59        60      Teli Tanuj Deepak            61          52            52
# 60        61    Varthe Tushar Vinod            41          41            41
# 61        62       Wade Ritesh Ravi            65          52            56
# 62        63  Yedre Shreyas Subhash            49          55            68
#
#     Maths(100)  Science(100)  Social Science(100)  Art(100)  \
# 58          41            49                   53        89
# 59          41            41                   42        74
# 60          41            41                   41        74
# 61          41            43                   41        82
# 62          44            41                   41        85
#
#     Work Experience(100)  Health Education(100)  Total(900)  \
# 58                    59                     82         547
# ...

# %%
dataset_7B.shape
# Out:
# (63, 16)

# %%
print("Number of Rows:",dataset_7B.shape[0])
print("Number of Columns:",dataset_7B.shape[1])
# Out:
# Number of Rows: 63
# Number of Columns: 16

# %%
dataset_7B.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Roll No.                63 non-null     int64
#  1   Student Name            63 non-null     object
#  2   Marathi(100)            63 non-null     int64
#  3   Hindi(100)              63 non-null     int64
#  4   English(100)            63 non-null     int64
#  5   Maths(100)              63 non-null     int64
#  6   Science(100)            63 non-null     int64
#  7   Social Science(100)     63 non-null     int64
#  8   Art(100)                63 non-null     int64
#  9   Work Experience(100)    63 non-null     int64
#  10  Health Education(100)   63 non-null     int64
#  11  Total(900)              63 non-null     int64
#  12  No. of Subjects Failed  63 non-null     object
#  13  Percentage(100%)        63 non-null     float64
# ...

# %%
dataset_7B.isnull().sum()
# Out:
# Roll No.                  0
# Student Name              0
# Marathi(100)              0
# Hindi(100)                0
# English(100)              0
# Maths(100)                0
# Science(100)              0
# Social Science(100)       0
# Art(100)                  0
# Work Experience(100)      0
# Health Education(100)     0
# Total(900)                0
# No. of Subjects Failed    0
# Percentage(100%)          0
# Grade                     0
# Remark                    0
# dtype: int64

# %%
dataset_7B_dup=dataset_7B.duplicated().any()
print(dataset_7B_dup)
# Out:
# False

# %%
dataset_7B.describe()
# Out:
#         Roll No.  Marathi(100)  Hindi(100)  English(100)  Maths(100)  \
# count  63.000000     63.000000   63.000000     63.000000   63.000000
# mean   32.000000     63.952381   57.190476     60.460317   50.222222
# std    18.330303     13.849920   12.782116     13.576338    9.065077
# min     1.000000     41.000000   41.000000     41.000000   41.000000
# 25%    16.500000     53.500000   46.000000     49.500000   43.000000
# 50%    32.000000     64.000000   55.000000     61.000000   47.000000
# 75%    47.500000     75.500000   67.000000     70.500000   57.000000
# max    63.000000     92.000000   87.000000     90.000000   78.000000
#
#        Science(100)  Social Science(100)   Art(100)  Work Experience(100)  \
# count     63.000000            63.000000  63.000000             63.000000
# mean      45.444444            49.365079  80.206349             70.444444
# std        6.948608            12.310894   8.299162             14.572154
# ...

# %%
#8TH STANDARD

# %%
dataset_8A.head()
# Out:
#    Roll No.            Student Name  Marathi(60)  Hindi(60)  English(60)  \
# 0         1     Adulkar Sayali Ajit           48         42           44
# 1         2  Bansode Shweta Sahadev           46         44           43
# 2         3  Bhagate Shruti Santosh           42         34           42
# 3         4      Bhaip Ishwari Arun           44         42           48
# 4         5       Dalvi Arya Suresh           54         48           48
#
#    Maths(60)  Science(60)  Social Science(60)  Art(100)  Work Experience(100)  \
# 0         27           23                  35        84                    81
# 1         18           26                  34        79                    97
# 2         27           22                  34        89                    88
# 3         26           33                  37        75                    87
# 4         55           52                  56        86                    85
#
# ...

# %%
dataset_8A.tail()
# Out:
#     Roll No.              Student Name  Marathi(60)  Hindi(60)  English(60)  \
# 66        67   Pawar Jayesh Nandkishor           45         46           50
# 67        68  Pawar Shravan Shashikant           46         28           53
# 68        69      Sagavekar Om Sandesh           34         39           32
# 69        70       Taral Kunal Mangesh           44         28           43
# 70        71         Teli Akhil Laxman           31         50           42
#
#     Maths(60)  Science(60)  Social Science(60)  Art(100)  \
# 66         29           31                  45        79
# 67         42           39                  49        80
# 68         14           26                  24        77
# 69         30           33                  34        77
# 70         21           23                  25        79
#
#     Work Experience(100)  Health Education(100)  Total(360)  \
# 66                    90                     90         246
# ...

# %%
dataset_8A.shape
# Out:
# (71, 16)

# %%
print("Number of Rows:",dataset_8A.shape[0])
print("Number of Columns:",dataset_8A.shape[1])
# Out:
# Number of Rows: 71
# Number of Columns: 16

# %%
dataset_8A.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Roll No.                71 non-null     int64
#  1   Student Name            71 non-null     object
#  2   Marathi(60)             71 non-null     int64
#  3   Hindi(60)               71 non-null     int64
#  4   English(60)             71 non-null     int64
#  5   Maths(60)               71 non-null     int64
#  6   Science(60)             71 non-null     int64
#  7   Social Science(60)      71 non-null     int64
#  8   Art(100)                71 non-null     int64
#  9   Work Experience(100)    71 non-null     int64
#  10  Health Education(100)   71 non-null     int64
#  11  Total(360)              71 non-null     int64
#  12  No. of Subjects Failed  71 non-null     int64
#  13  Percentage(100%)        71 non-null     float64
# ...

# %%
dataset_8A.isnull().sum()
# Out:
# Roll No.                  0
# Student Name              0
# Marathi(60)               0
# Hindi(60)                 0
# English(60)               0
# Maths(60)                 0
# Science(60)               0
# Social Science(60)        0
# Art(100)                  0
# Work Experience(100)      0
# Health Education(100)     0
# Total(360)                0
# No. of Subjects Failed    0
# Percentage(100%)          0
# Grade                     0
# Remark                    0
# dtype: int64

# %%
dataset_8A_dup=dataset_8A.duplicated().any()
print(dataset_8A_dup)
# Out:
# False

# %%
dataset_8A.describe()
# Out:
#         Roll No.  Marathi(60)  Hindi(60)  English(60)  Maths(60)  Science(60)  \
# count  71.000000    71.000000  71.000000    71.000000  71.000000    71.000000
# mean   36.000000    43.338028  41.211268    45.774648  31.845070    30.943662
# std    20.639767     6.731469   6.335649     5.877796  10.637733     8.261593
# min     1.000000    23.000000  26.000000    31.000000  11.000000    14.000000
# 25%    18.500000    39.000000  38.000000    42.500000  25.000000    24.000000
# 50%    36.000000    44.000000  42.000000    47.000000  29.000000    31.000000
# 75%    53.500000    49.000000  47.000000    50.000000  41.000000    36.500000
# max    71.000000    54.000000  52.000000    55.000000  55.000000    52.000000
#
#        Social Science(60)   Art(100)  Work Experience(100)  \
# count           71.000000  71.000000             71.000000
# mean            41.056338  81.267606             83.070423
# std              9.053630   8.402309              8.655839
# ...

# %%
dataset_8B.head()
# Out:
#    Roll No.             Student Name  Marathi(60)  Hindi(60)  English(60)  \
# 0         1      Agre Sharyali Sunil           37         29           34
# 1         2     Ambekar Kritika Anil           42         35           36
# 2         3    Bamane Anushka Prasad           26         23           23
# 3         4  Barthare Harshita Vijay           38         28           29
# 4         5     Chavan Vidhi Sitaram           38         32           33
#
#    Maths(60)  Science(60)  Social Science(60)  Art(100)  Work Experience(100)  \
# 0         25           31                  31        92                    88
# 1         28           31                  37        78                    79
# 2         18           21                  25        78                    74
# 3         17           25                  16        90                    78
# 4         16           26                  25        54                    71
#
# ...

# %%
dataset_8B.tail()
# Out:
#     Roll No.             Student Name  Marathi(60)  Hindi(60)  English(60)  \
# 70        71   Sangre Aradhya Mangesh           25         21            3
# 71        72  Sapkal Bhavesh Raosaheb           30         24           16
# 72        73  Shelar Sanket Dynanadev           23         27           21
# 73        74     Tarfe Hardik Sandeep           38         28           25
# 74        75      Vanse Sunny Sandeep           21          8            3
#
#     Maths(60)  Science(60)  Social Science(60)  Art(100)  \
# 70         16           25                  17        76
# 71         29           26                  22        81
# 72         21           24                  22        73
# 73         17           48                  27        75
# 74         15           17                  15        77
#
#     Work Experience(100)  Health Education(100)  Total(360)  \
# 70                    54                     72         107
# ...

# %%
dataset_8B.shape
# Out:
# (75, 16)

# %%
print("Number of Rows:",dataset_8B.shape[0])
print("Number of Columns:",dataset_8B.shape[1])
# Out:
# Number of Rows: 75
# Number of Columns: 16

# %%
dataset_8B.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Roll No.                75 non-null     int64
#  1   Student Name            75 non-null     object
#  2   Marathi(60)             75 non-null     int64
#  3   Hindi(60)               75 non-null     int64
#  4   English(60)             75 non-null     int64
#  5   Maths(60)               75 non-null     int64
#  6   Science(60)             75 non-null     int64
#  7   Social Science(60)      75 non-null     int64
#  8   Art(100)                75 non-null     int64
#  9   Work Experience(100)    75 non-null     int64
#  10  Health Education(100)   75 non-null     int64
#  11  Total(360)              75 non-null     int64
#  12  No. of Subjects Failed  75 non-null     int64
#  13  Percentage(100%)        75 non-null     float64
# ...

# %%
dataset_8B.isnull().sum()
# Out:
# Roll No.                  0
# Student Name              0
# Marathi(60)               0
# Hindi(60)                 0
# English(60)               0
# Maths(60)                 0
# Science(60)               0
# Social Science(60)        0
# Art(100)                  0
# Work Experience(100)      0
# Health Education(100)     0
# Total(360)                0
# No. of Subjects Failed    0
# Percentage(100%)          0
# Grade                     0
# Remark                    0
# dtype: int64

# %%
dataset_8B_dup=dataset_8B.duplicated().any()
print(dataset_8B_dup)
# Out:
# False

# %%
dataset_8B.describe()
# Out:
#         Roll No.  Marathi(60)  Hindi(60)  English(60)  Maths(60)  Science(60)  \
# count  75.000000    75.000000  75.000000    75.000000  75.000000    75.000000
# mean   38.000000    33.986667  28.986667    26.946667  22.280000    26.306667
# std    21.794495    10.180125  10.086777    10.655405   7.946714     8.770302
# min     1.000000     4.000000   8.000000     3.000000   7.000000    11.000000
# 25%    19.500000    26.000000  22.000000    21.000000  17.000000    20.500000
# 50%    38.000000    35.000000  28.000000    27.000000  21.000000    25.000000
# 75%    56.500000    42.000000  35.500000    35.000000  26.000000    31.000000
# max    75.000000    53.000000  53.000000    55.000000  51.000000    50.000000
#
#        Social Science(60)   Art(100)  Work Experience(100)  \
# count           75.000000  75.000000             75.000000
# mean            27.853333  78.773333             72.760000
# std             11.261863   6.172242             11.951298
# ...

# %%
dataset_9A.head()
# Out:
#    Roll No.               Student Name  Marathi(100)  Hindi(100)  \
# 0         1        Bhogal Anshu Ankush            70          64
# 1         2        Bhuvad Riya Shankar            76          71
# 2         3      Chode Harshada Satish            82          82
# 3         4    Deshmukh Sonal Gaurihar            81          79
# 4         5  Devale Vaishnavi Sakharam            51          42
#
#    English(100)  Maths(100)  Science(100)  Social Science(100)  \
# 0            48          64            60                   80
# 1            56          57            73                   73
# 2            69          84            91                   92
# 3            72          79            93                   90
# 4            42          41            50                   55
#
#    Health Education(100)  Water Security(100)  Defense Education(100)  \
# 0                     93                   87                      91
# ...

# %%
dataset_9A.tail()
# Out:
#     Roll No.                Student Name  Marathi(100)  Hindi(100)  \
# 60        61    Rajapakar Aryan Ravindra            53          46
# 61        62  Sambare Shubham Shasikanth            59          47
# 62        63        Sarvade Aniket Gopal            35          37
# 63        64       Telvekar Sahil Sanjay            54          48
# 64        65      Tirlotkar Rudra Sachin            72          66
#
#     English(100)  Maths(100)  Science(100)  Social Science(100)  \
# 60            41          37            44                   50
# 61            47          40            48                   54
# 62            33          34            36                   41
# 63            45          47            48                   54
# 64            61          59            63                   63
#
#     Health Education(100)  Water Security(100)  Defense Education(100)  \
# 60                     82                   90                      92
# ...

# %%
dataset_9A.shape
# Out:
# (65, 16)

# %%
print("Number of Rows:",dataset_9A.shape[0])
print("Number of Columns:",dataset_9A.shape[1])
# Out:
# Number of Rows: 65
# Number of Columns: 16

# %%
dataset_9A.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Roll No.                65 non-null     int64
#  1   Student Name            65 non-null     object
#  2   Marathi(100)            65 non-null     int64
#  3   Hindi(100)              65 non-null     int64
#  4   English(100)            65 non-null     int64
#  5   Maths(100)              65 non-null     int64
#  6   Science(100)            65 non-null     int64
#  7   Social Science(100)     65 non-null     int64
#  8   Health Education(100)   65 non-null     int64
#  9   Water Security(100)     65 non-null     int64
#  10  Defense Education(100)  65 non-null     int64
#  11  Total(600)              65 non-null     int64
#  12  No. of Subjects Failed  65 non-null     object
#  13  Percentage(100%)        65 non-null     float64
# ...

# %%
dataset_9A.isnull().sum()
# Out:
# Roll No.                  0
# Student Name              0
# Marathi(100)              0
# Hindi(100)                0
# English(100)              0
# Maths(100)                0
# Science(100)              0
# Social Science(100)       0
# Health Education(100)     0
# Water Security(100)       0
# Defense Education(100)    0
# Total(600)                0
# No. of Subjects Failed    0
# Percentage(100%)          0
# Grade                     0
# Remark                    0
# dtype: int64

# %%
dataset_9A_dup=dataset_9A.duplicated().any()
print(dataset_9A_dup)
# Out:
# False

# %%
dataset_9A.describe()
# Out:
#        Roll No.  Marathi(100)  Hindi(100)  English(100)  Maths(100)  \
# count  65.00000     65.000000   65.000000     65.000000   65.000000
# mean   33.00000     64.892308   60.600000     54.076923   56.015385
# std    18.90767     13.353514   12.716623     12.189016   13.238783
# min     1.00000     35.000000   35.000000     29.000000   34.000000
# 25%    17.00000     54.000000   52.000000     47.000000   45.000000
# 50%    33.00000     68.000000   60.000000     53.000000   55.000000
# 75%    49.00000     77.000000   70.000000     63.000000   67.000000
# max    65.00000     86.000000   87.000000     80.000000   84.000000
#
#        Science(100)  Social Science(100)  Health Education(100)  \
# count     65.000000            65.000000              65.000000
# mean      60.061538            65.784615              87.523077
# std       14.253154            13.576741               5.262211
# min       36.000000            41.000000              80.000000
# ...

# %%
dataset_9B.head()
# Out:
#    Roll No.            Student Name  Marathi(100)  Hindi(100)  English(100)  \
# 0         1     Agre Tejashwi Vijay            71          69            67
# 1         2  Ambelkar Tanvi Subhash            52          50            39
# 2         3      Ayre Aarti Jaywant            44          35            30
# 3         4     Ayre Rohini Jaywant            31          32            25
# 4         5  Bhagat Malishka Hemant            40          43            37
#
#    Maths(100)  Science(100)  Social Science(100)  Health Education(100)  \
# 0          51            67                   64                     93
# 1          36            41                   48                     98
# 2          26            32                   35                     98
# 3          21            29                   30                     94
# 4          30            44                   41                     88
#
#    Water Security(100)  Defense Education(100)  Total(600)  \
# ...

# %%
dataset_9B.tail()
# Out:
#     Roll No.             Student Name  Marathi(100)  Hindi(100)  English(100)  \
# 70        71     Habale Roshni Suresh             0           0             0
# 71        72     Ghag Omkar Prabhakar             0           0             0
# 72        73  Lakhan Siddesh Dashrath             0           0             0
# 73        74     Morya Manish Vasudev             0           0             0
# 74        75     Khanjode Ritesh Ravi             0           0             0
#
#     Maths(100)  Science(100)  Social Science(100)  Health Education(100)  \
# 70           0             0                    0                      0
# 71           0             0                    0                      0
# 72           0             0                    0                      0
# 73           0             0                    0                      0
# 74           0             0                    0                      0
#
# ...

# %%
dataset_9B.shape
# Out:
# (75, 16)

# %%
print("Number of Rows:",dataset_9B.shape[0])
print("Number of Columns:",dataset_9B.shape[1])
# Out:
# Number of Rows: 75
# Number of Columns: 16

# %%
dataset_9B.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Roll No.                75 non-null     int64
#  1   Student Name            75 non-null     object
#  2   Marathi(100)            75 non-null     int64
#  3   Hindi(100)              75 non-null     int64
#  4   English(100)            75 non-null     int64
#  5   Maths(100)              75 non-null     int64
#  6   Science(100)            75 non-null     int64
#  7   Social Science(100)     75 non-null     int64
#  8   Health Education(100)   75 non-null     int64
#  9   Water Security(100)     75 non-null     int64
#  10  Defense Education(100)  75 non-null     int64
#  11  Total(600)              75 non-null     int64
#  12  No. of Subjects Failed  75 non-null     object
#  13  Percentage(100%)        75 non-null     float64
# ...

# %%
dataset_9B.isnull().sum()
# Out:
# Roll No.                  0
# Student Name              0
# Marathi(100)              0
# Hindi(100)                0
# English(100)              0
# Maths(100)                0
# Science(100)              0
# Social Science(100)       0
# Health Education(100)     0
# Water Security(100)       0
# Defense Education(100)    0
# Total(600)                0
# No. of Subjects Failed    0
# Percentage(100%)          0
# Grade                     0
# Remark                    0
# dtype: int64

# %%
dataset_9B.isnull().sum()
# Out:
# Roll No.                  0
# Student Name              0
# Marathi(100)              0
# Hindi(100)                0
# English(100)              0
# Maths(100)                0
# Science(100)              0
# Social Science(100)       0
# Health Education(100)     0
# Water Security(100)       0
# Defense Education(100)    0
# Total(600)                0
# No. of Subjects Failed    0
# Percentage(100%)          0
# Grade                     0
# Remark                    0
# dtype: int64

# %%
dataset_9B_dup=dataset_9B.duplicated().any()
print(dataset_9B_dup)
# Out:
# False

# %%
dataset_9B.describe()
# Out:
#         Roll No.  Marathi(100)  Hindi(100)  English(100)  Maths(100)  \
# count  75.000000     75.000000   75.000000     75.000000   75.000000
# mean   38.000000     41.546667   40.546667     35.773333   32.226667
# std    21.794495     19.364424   17.949097     15.637423   13.054536
# min     1.000000      0.000000    0.000000      0.000000    0.000000
# 25%    19.500000     31.500000   32.000000     28.500000   29.000000
# 50%    38.000000     46.000000   45.000000     37.000000   34.000000
# 75%    56.500000     55.000000   51.000000     46.000000   41.000000
# max    75.000000     72.000000   70.000000     67.000000   56.000000
#
#        Science(100)  Social Science(100)  Health Education(100)  \
# count     75.000000            75.000000              75.000000
# mean      34.280000            37.213333              80.480000
# std       14.785457            15.719925              24.450369
# min        0.000000             0.000000               0.000000
# ...

# %%
dataset_overall.head()
# Out:
#    Sr.no.  Roll No.               Student Name  Class  Gender  \
# 0       1         1       Arde Netra Satyawan       5  Female
# 1       2         2  Baraskar Vidhi Shashikant      5  Female
# 2       3         3   Bhekere Shravani Nilesh       5  Female
# 3       4         4       Chavan Purvi Rupesh       5  Female
# 4       5         5   Deshmukh Swara Gaurihar       5  Female
#
#   No. of Subjects Failed  Percentage(100%)  Grade Remark
# 0                      -               59.6     D   Pass
# 1                      -               66.0     C   Pass
# 2                      -               72.0     B   Pass
# 3                      -               74.0     B   Pass
# 4                      -               89.2     A   Pass

# %%
dataset_overall.tail()
# Out:
#      Sr.no.  Roll No.             Student Name  Class Gender  \
# 629     630        71     Habale Roshni Suresh      9   Male
# 630     631        72     Ghag Omkar Prabhakar      9   Male
# 631     632        73  Lakhan Siddesh Dashrath      9   Male
# 632     633        74     Morya Manish Vasudev      9   Male
# 633     634        75     Khanjode Ritesh Ravi      9   Male
#
#     No. of Subjects Failed  Percentage(100%)  Grade   Remark
# 629                      6                0.0     F  Re-exam
# 630                      6                0.0     F  Re-exam
# 631                      6                0.0     F  Re-exam
# 632                      6                0.0     F  Re-exam
# 633                      6                0.0     F  Re-exam

# %%
dataset_overall.shape
# Out:
# (634, 9)

# %%
print("Number of Rows:",dataset_overall.shape[0])
print("Number of Columns:",dataset_overall.shape[1])
# Out:
# Number of Rows: 634
# Number of Columns: 9

# %%
dataset_overall.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 634 entries, 0 to 633
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Sr.no.                  634 non-null    int64
#  1   Roll No.                634 non-null    int64
#  2   Student Name            634 non-null    object
#  3   Class                   634 non-null    int64
#  4   Gender                  634 non-null    object
#  5   No. of Subjects Failed  597 non-null    object
#  6   Percentage(100%)        634 non-null    float64
#  7   Grade                   634 non-null    object
#  8   Remark                  634 non-null    object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 44.7+ KB

# %%
dataset_overall.isnull().sum()
# Out:
# Sr.no.                     0
# Roll No.                   0
# Student Name               0
# Class                      0
# Gender                     0
# No. of Subjects Failed    37
# Percentage(100%)           0
# Grade                      0
# Remark                     0
# dtype: int64

# %%
dataset_overall_dup=dataset_overall.duplicated().any()
print(dataset_overall_dup)
# Out:
# False

# %%
dataset_overall.describe()
# Out:
#            Sr.no.    Roll No.       Class  Percentage(100%)
# count  634.000000  634.000000  634.000000         634.000000
# mean   317.500000   32.861199    7.138801          59.514914
# std    183.164316   19.351810    1.417441          17.228219
# min      1.000000    1.000000    5.000000           0.000000
# 25%    159.250000   16.000000    6.000000          48.527778
# 50%    317.500000   32.000000    7.000000          62.366667
# 75%    475.750000   48.000000    8.000000          72.111111
# max    634.000000   75.000000    9.000000          92.400000

# %%
dataset_5A.to_excel('cleaned_data.xlsx',sheet_name="5A", index=False)
dataset_5B.to_excel('cleaned_data.xlsx',sheet_name="5B", index=False)
dataset_6A.to_excel('cleaned_data.xlsx',sheet_name="6A", index=False)
dataset_6B.to_excel('cleaned_data.xlsx',sheet_name="6B", index=False)
dataset_7A.to_excel('cleaned_data.xlsx',sheet_name="7A", index=False)
dataset_7B.to_excel('cleaned_data.xlsx',sheet_name="7B", index=False)
dataset_8A.to_excel('cleaned_data.xlsx',sheet_name="8A", index=False)
dataset_8B.to_excel('cleaned_data.xlsx',sheet_name="8B", index=False)
dataset_9A.to_excel('cleaned_data.xlsx',sheet_name="9A", index=False)
dataset_9B.to_excel('cleaned_data.xlsx',sheet_name="9B", index=False)
dataset_overall.to_excel('cleaned_data.xlsx',sheet_name="Overall", index=False)
